# %% [markdown]
# <a href="https://colab.research.google.com/github/Gizeh-Gutierrez/Maestria_programacion/blob/main/Sesion12_Evaluacion_Datos_Categoricos_271752.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Programación para Analítica Descriptiva y Predictiva**
# **Maestría en Inteligencia Artificial y Analítica de Datos**
#
# # Sesión 12: Evaluación — Limpieza y Transformación de Datos Categóricos
#
# **Entrega individual**
#
# - **Nombre**:Gizeh Gutierrez
# - **Matrícula** 271752
#
# Esta evaluación aplica los tres temas de la Sesión 12 (errores tipográficos y valores inconsistentes, alta cardinalidad, tipos incorrectos) a un dataset que no se trabajó en clase: **Telco Customer Churn**.
#
#
# No hay una única respuesta correcta en varias de las actividades — lo que se evalúa es que la conclusión esté respaldada por el código que la sustenta, no solo la conclusión en sí.

# %% [markdown]
# ## Preparación

# %%
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/treselle-systems/customer_churn_analysis/master/WA_Fn-UseC_-Telco-Customer-Churn.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# ---
# ## Actividad 1 — Formato y valores inconsistentes (15 pts)
#
# Revisa **todas** las columnas categóricas del dataset (no elijas solo una) en busca de variantes de formato (mayúsculas, espacios) que deberían normalizarse.

# %%
# 1.1 — Recorre todas las columnas categóricas con .value_counts() o .unique()
# para inspeccionar sus valores.

for col in cat_cols:
  print(f"\n{'='*50}")
  print(f"Columna: {col}")
  print(df[col].value_counts(dropna=False))
# Out:
# ==================================================
# Columna: customerID
# customerID
# 3186-AJIEK    1
# 7590-VHVEG    1
# 5575-GNVDE    1
# 8775-CEBBJ    1
# 2823-LKABH    1
#              ..
# 6713-OKOMC    1
# 1452-KIOVK    1
# 9305-CDSKC    1
# 9237-HQITU    1
# 7795-CFOCW    1
# Name: count, Length: 7043, dtype: int64
#
# ==================================================
# Columna: gender
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
# ==================================================
# Columna: Partner
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# ==================================================
# Columna: Dependents
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# ==================================================
# Columna: PhoneService
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
#
# ==================================================
# Columna: MultipleLines
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64
#
# ==================================================
# Columna: InternetService
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: OnlineSecurity
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: OnlineBackup
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: DeviceProtection
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: TechSupport
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: StreamingTV
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: StreamingMovies
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64
#
# ==================================================
# Columna: Contract
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# ==================================================
# Columna: PaperlessBilling
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64
#
# ==================================================
# Columna: PaymentMethod
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64
#
# ==================================================
# Columna: TotalCharges
# TotalCharges
#            11
# 20.2       11
# 19.75       9
# 20.05       8
# 19.9        8
#            ..
# 130.15      1
# 3211.9      1
# 7843.55     1
# 2196.3      1
# 197.4       1
# Name: count, Length: 6531, dtype: int64
#
# ==================================================
# Columna: Churn
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
for col in cat_cols:
    espacios = (df[col] != df[col].str.strip()).sum()
    print(f"{col}: {espacios} valores con espacios")
# Out:
# customerID: 0 valores con espacios
# gender: 0 valores con espacios
# Partner: 0 valores con espacios
# Dependents: 0 valores con espacios
# PhoneService: 0 valores con espacios
# MultipleLines: 0 valores con espacios
# InternetService: 0 valores con espacios
# OnlineSecurity: 0 valores con espacios
# OnlineBackup: 0 valores con espacios
# DeviceProtection: 0 valores con espacios
# TechSupport: 0 valores con espacios
# StreamingTV: 0 valores con espacios
# StreamingMovies: 0 valores con espacios
# Contract: 0 valores con espacios
# PaperlessBilling: 0 valores con espacios
# PaymentMethod: 0 valores con espacios
# TotalCharges: 11 valores con espacios
# Churn: 0 valores con espacios

# %%
for col in cat_cols:
xqs', '0278-yxoog', '0280-xjgex', '0281-cntzx', '0282-nvsjs', '0285-inhln', '0289-ivarm', '0292-wegch', '0295-pphdo', '0295-qvkpb', '0297-rbcsg', '0298-xacet', '0301-fidrb', '0301-kobtq', '0302-joivn', '0303-uncip', '0303-wmmrn', '0305-sqecb', '0306-jaele', '0307-bcopk', '0308-giqjt', '0308-ivgok', '0310-mvlet', '0310-sucin', '0310-vqxam', '0311-qywss', '0311-unpff', '0314-tkosi', '0315-lvcrk', '0318-quuob', '0318-zopws', '0319-qztco', '0320-dwvtu', '0320-jdnqg', '0322-chqru', '0322-yinqp', '0323-xwwtn', '0324-brpcj', '0325-xbfac', '0326-vdyxe', '0327-wfzsy', '0328-grpmv', '0329-gtiaj', '0330-bgyze', '0330-ivzha', '0334-gddso', '0334-zfjsr', '0336-kxkfk', '0336-pikei', '0337-cnpze', '0343-qluzp', '0345-hkjvm', '0345-xmmug', '0347-ubkuz', '0348-sdkol', '0354-vxmjc', '0354-wyrok', '0356-erhvt', '0356-obmac', '0357-nvcri', '0361-hjrdx', '0362-raoqo', '0362-zbzwj', '0363-qjvfx', '0363-svhyr', '0365-bzuwy', '0365-gxezs', '0365-trtpy', '0366-nqshs', '0369-zgovk', '0373-aivnj', '0374-aacsz', '0374-fiuca', '0374-ioegq', '0375-hvgxo', '0376-oiwme', '0376-ymcjc', '0377-jbkkt', '0378-cjkpv', '0378-nhqxu', '0378-tovms', '0378-xszpu', '0379-djqhr', '0380-neavx', '0380-zcsbi', '0383-cldda', '0384-lpite', '0384-rvbpi', '0386-cwrgm', '0388-eopex', '0390-dcfdq', '0392-bziuw', '0394-yondk', '0396-hujbp', '0396-ukgai', '0396-ychwo', '0397-gzbbc', '0397-zxwqf', '0401-wdbxm', '0402-cqajn', '0402-oamen', '0404-ahasp', '0404-swrvg', '0406-bpdvr', '0407-bdjkb', '0409-wtmpl', '0410-ipfty', '0411-ezjze', '0412-uccnp', '0415-mosgf', '0419-yaapx', '0420-bwtpw', '0420-hlgxf', '0420-txv ...
#
# gender
# ['female', 'male']
#
# Partner
# ['no', 'yes']
#
# Dependents
# ['no', 'yes']
#
# PhoneService
# ['no', 'yes']
#
# MultipleLines
# ['no', 'no phone service', 'yes']
#
# InternetService
# ['dsl', 'fiber optic', 'no']
#
# OnlineSecurity
# ['no', 'no internet service', 'yes']
#
# OnlineBackup
# ['no', 'no internet service', 'yes']
#
# DeviceProtection
# ['no', 'no internet service', 'yes']
#
# TechSupport
# ['no', 'no internet service', 'yes']
#
# StreamingTV
# ['no', 'no internet service', 'yes']
#
# StreamingMovies
# ['no', 'no internet service', 'yes']
#
# Contract
# ['month-to-month', 'one year', 'two year']
#
# PaperlessBilling
# ['no', 'yes']
#
# PaymentMethod
# ['bank transfer (automatic)', 'credit card (automatic)', 'electronic check', 'mailed check']
#
# TotalCharges
165.6', '1165.9', '1166.7', '1167.6', '1167.8', '1169.35', '117.05', '117.8', '117.95', '1170.5', '1170.55', '1171.3', '1171.5', '1172.95', '1173.35', '1173.55', '1174.35', '1174.8', '1175.6', '1175.85', '1177.05', '1177.95', '1178.25', '1178.4', '1178.75', '118.25', '118.3', '118.4', '118.5', '1180.95', '1181.75', '1182.55', '1183.05', '1183.2', '1183.8', '1184', '1185', '1185.95', '1187.05', '1188.2', '1188.25', '1189.4', '1189.9', '119.3', '119.5', '119.75', '1190.5', '1191.2', '1191.4', '1192.3', '1192.7', '1193.05', '1193.55', '1194.3', '1195.25', '1195.75', '1195.95', '1198.05', '1198.8', '1199.4', '120.25', '1200.15', '1201.15', '1201.65', '1203.9', '1203.95', '1205.05', '1205.5', '1206.05', '1207', '1208.15', '1208.35', '1208.6', '1209.25', '121.25', '1210.3', '1210.4', '1211.65', '1212.1', '1212.25', '1212.85', '1214.05' ...
#
# Churn
# ['no', 'yes']

# %% [markdown]
# **1.2 — Conclusión (responde aquí en Markdown):**
#
# ¿Encontraste alguna columna con inconsistencias de formato? Si sí, ¿cuál y qué código usarías para corregirla? Si no encontraste ninguna, dilo explícitamente — es una conclusión válida siempre que esté respaldada por lo que revisaste en 1.1.
#
# _Tu respuesta:_ **La mayoría de las variables del dataset están limpias, sin diferencias de mayúsculas, minúsculas o espacios. La principal inconsistencia se encuentra en TotalCharges, que contiene valores en blanco, haciendo que la columna se interprete como texto en lugar de numérica.**

# %% [markdown]
# ---
# ## Actividad 2 — Valores inválidos (20 pts)
#
# Varias columnas de este dataset (`OnlineSecurity`, `OnlineBackup`, `DeviceProtection`, `TechSupport`, `StreamingTV`, `StreamingMovies`) tienen un tercer valor además de `'Yes'`/`'No'`: `'No internet service'`. De forma similar, `MultipleLines` tiene `'No phone service'`.

# %%
df['OnlineSecurity'].value_counts()

# %%
# 2.1 — Verifica: ¿las filas con 'No internet service' en OnlineSecurity
# coinciden con las filas donde InternetService == 'No'?
# (pista: cruza ambas columnas con pd.crosstab o filtrando)

pd.crosstab(df['OnlineSecurity'], df['InternetService'])
# Out:
# InternetService       DSL  Fiber optic    No
# OnlineSecurity
# No                   1241         2257     0
# No internet service     0            0  1526
# Yes                  1180          839     0

# %% [markdown]
# **2.2 — Conclusión (responde aquí en Markdown):**
#
# ¿`'No internet service'` es un valor inválido (como `Absurd`/`YOLO` en la sesión de clase) o es una categoría legítima? Justifica tu respuesta con lo que verificaste en 2.1. ¿Tomarías alguna acción sobre esta columna, o la dejarías tal cual?
#
# _Tu respuesta:_ **"No internet service" es una categoría correcta. La verificación realizada muestra que estos registros coinciden con clientes cuyo InternetService es "No", por lo que el valor tiene sentido.
# La accion que tomaria seria recodificar como "No" para simplificar.**

# %% [markdown]
# ---
# ## Actividad 3 — Alta cardinalidad (25 pts)

# %%
# 3.1 — Calcula .nunique() para TODAS las columnas del dataset (no solo las categóricas)
# y la razón (valores únicos / total de filas) para cada una.


n_filas = len(df)

categorias = pd.DataFrame({
    'Valores_Unicos': df.nunique(),
    'Razon_Unicos': df.nunique() / n_filas
}).sort_values('Razon_Unicos', ascending=False)

categorias
# Out:
#                   Valores_Unicos  Razon_Unicos
# customerID                  7043      1.000000
# TotalCharges                6531      0.927304
# MonthlyCharges              1585      0.225046
# tenure                        73      0.010365
# PaymentMethod                  4      0.000568
# StreamingMovies                3      0.000426
# TechSupport                    3      0.000426
# OnlineBackup                   3      0.000426
# StreamingTV                    3      0.000426
# DeviceProtection               3      0.000426
# MultipleLines                  3      0.000426
# InternetService                3      0.000426
# OnlineSecurity                 3      0.000426
# Contract                       3      0.000426
# Partner                        2      0.000284
# SeniorCitizen                  2      0.000284
# gender                         2      0.000284
# Dependents                     2      0.000284
# PhoneService                   2      0.000284
# PaperlessBilling               2      0.000284
# Churn                          2      0.000284

# %% [markdown]
# **3.2 — Conclusión (responde aquí en Markdown):**
#
# ¿Qué columna(s) tienen alta cardinalidad? Para la columna con mayor cardinalidad: ¿por qué nunca deberías usarla como variable predictora en un modelo, incluso si la codificaras? (relaciona tu respuesta con lo discutido en clase sobre identificadores únicos)
#
# _Tu respuesta:_ **La columna con mayor cantidad de valores únicos (mayor cardinalidad) es customerID, ya que cada cliente tiene un identificador diferente.**
#
# **No debería usarse como variable predictora porque es un identificador único y no contiene información real sobre el comportamiento o las características del cliente. Aunque se codificara numéricamente, el modelo memorizaria  a clientes específicos en lugar de aprender patrones generales.**

# %% [markdown]
# **3.3 — Agrupación "Top 10 + Otros"**
#
# En clase agrupaste `country` de Netflix Titles en sus 10 categorías más frecuentes + `'Otros'`, reduciendo su cardinalidad. Aplica la misma técnica aquí sobre la columna de mayor cardinalidad que identificaste en 3.1 (pista: `.value_counts().head(10)`, luego `.where()` + `.isin()`, igual que en el notebook de clase).

# %%
# Aplica el agrupamiento Top 10 + Otros sobre la columna de mayor cardinalidad

top_10 = df['customerID'].value_counts().head(10).index

df['customerID_agrupado'] = df['customerID'].where(
    df['customerID'].isin(top_10),
    'Otros'
)

df['customerID_agrupado'].value_counts()
# Out:
# customerID_agrupado
# Otros         7033
# 7590-VHVEG       1
# 5575-GNVDE       1
# 9837-FWLCH       1
# 1699-HPSBG       1
# 7203-OYKCT       1
# 1035-IPQPU       1
# 7398-LXGYX       1
# 2823-LKABH       1
# 8775-CEBBJ       1
# 3186-AJIEK       1
# Name: count, dtype: int64

# %% [markdown]
# **3.4 — Conclusión (responde aquí en Markdown):**
#
# Después de agrupar, ¿la columna resultante te parece útil para un modelo? Compara este caso con el de `country` en el notebook de clase: ¿por qué agrupar en "Top 10 + Otros" funciona bien para una variable como `country`, pero no resuelve el problema real de la columna que agrupaste aquí?
#
# _Tu respuesta:_ **No, la columna sigue sin ser útil para un modelo porque proviene de un identificador (customerID) y no aporta información sobre el cliente.**
#
# **En country, agrupar en "Top 10 + Otros" funciona porque el país sí tiene significado para el análisis. En cambio, en customerID, la agrupación no resuelve el problema, ya que sigue siendo un identificador único.**

# %% [markdown]
# ---
# ## Actividad 4 — Tipos de dato (30 pts)

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %% [markdown]
# **4.1 — Investiga (responde en Markdown):**
#
# `TotalCharges` contiene valores numéricos (montos en dólares), pero pandas la cargó como `object`, no como `float`. Investiga por qué — revisa si hay algún valor que no se vea como un número normal.
#
# _Tu respuesta:**La columna TotalCharges fue cargada como object porque contiene valores en blanco (" "), los cuales no pueden interpretarse como números. Por esta razón, pandas no la convierte automáticamente a tipo float.**

# %%
# 4.2 — Corrige el tipo de TotalCharges.
# Pista: pd.to_numeric() con el parámetro errors= te puede ayudar a identificar
# o manejar los valores problemáticos que encontraste en 4.1.

# Convertir a numérico y reemplazar valores inválidos por NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Verificar el nuevo tipo de dato
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %%
# 4.3 — Convierte a category las columnas categóricas que, según lo que calculaste
# en la Actividad 3, tengan cardinalidad baja y valores fijos.
# Verifica con .dtypes que el cambio se aplicó correctamente.
# Seleccionar columnas categóricas con pocos valores únicos
cols_category = [
    col for col in df.select_dtypes(include='object').columns
    if df[col].nunique() < 20 and col != 'customerID'
]

# Convertir a category
df[cols_category] = df[cols_category].astype('category')

# Verificar tipos de datos
df[cols_category].dtypes
# Out:
# gender                 category
# Partner                category
# Dependents             category
# PhoneService           category
# MultipleLines          category
# InternetService        category
# OnlineSecurity         category
# OnlineBackup           category
# DeviceProtection       category
# TechSupport            category
# StreamingTV            category
# StreamingMovies        category
# Contract               category
# PaperlessBilling       category
# PaymentMethod          category
# Churn                  category
# customerID_agrupado    category
# dtype: object

# %% [markdown]
# ---
# ## Reflexión final (10 pts)
#
# Con base en las 4 actividades anteriores, responde:
#
# 1. De las alertas que detectaste (formato, valores inválidos, cardinalidad, tipos), ¿cuál te pareció más fácil de decidir y cuál más difícil? ¿Por qué?
# 2. Si tuvieras que entregar este dataset ya "perfilado" a un compañero para que construya un modelo predictivo, ¿qué le dirías sobre `customerID` y sobre `TotalCharges`?
#
# _Tu respuesta:_ **La alerta más fácil de identificar fue la de tipos de datos, ya que TotalCharges debía ser numérica pero fue cargada como object por tener valores en blanco.**
#
# **La más difícil fue la de cantidad de valores únicos, porque fue necesario analizar si la columna aportaba información útil o si solo identificaba registros.**
#
# **Si entregara este dataset, recomendaría eliminar customerID, porque es un identificador sin valor predictivo, y usar TotalCharges ya convertida a tipo numérico.**

# %% [markdown]
# ---
# ## Rúbrica de evaluación
#
# | Actividad | Puntos | Criterio |
# |---|---|---|
# | 1. Formato y valores inconsistentes | 15 | Revisó todas las columnas categóricas (no solo una); código comentado y conclusión (1.2) respaldada por lo que se observó, no solo afirmada |
# | 2. Valores inválidos | 20 | Verificó la relación entre columnas antes de concluir; la conclusión (2.2) justifica con evidencia, no solo con intuición |
# | 3. Alta cardinalidad | 25 | Calcula `.nunique()` para todas las columnas; aplica correctamente el agrupamiento Top 10 + Otros; la conclusión (3.4) explica por qué agrupar no resuelve el problema de un identificador único |
# | 4. Tipos de dato | 30 | Identifica la causa raíz del `dtype` incorrecto (4.1); corrige `TotalCharges` sin perder información; conversión a `category` justificada por cardinalidad, no aplicada al azar |
# | Reflexión final | 10 | Conecta las 4 actividades entre sí; no es una respuesta genérica o intercambiable con cualquier dataset |
# | **Total** | **100** | |
#
# **Nota sobre las conclusiones:** cada actividad tiene su propia pregunta de conclusión (1.2, 2.2, 3.4, 4.1) — esas respuestas se califican como parte de la actividad correspondiente, no solo la Reflexión final. Comenta tu código donde tomes una decisión (por ejemplo, por qué elegiste cierto umbral o cierta corrección) — el comentario también cuenta dentro del puntaje de cada actividad.
